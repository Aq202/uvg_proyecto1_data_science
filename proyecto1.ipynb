# %%
import pandas as pd
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_18872\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Lista de archivos CSV
files = [
    'altaverapaz.csv', 'guatemala.csv', 'quetzaltenango.csv', 'solola.csv',
    'baja_verapaz.csv', 'huehuetenango.csv', 'quiche.csv', 'suchitepequez.csv',
    'capital.csv', 'izabal.csv', 'retalhuleu.csv', 'totonicapan.csv',
    'chimaltenango.csv', 'jalapa.csv', 'sacatepequez.csv', 'zacapa.csv',
    'chiquimula.csv', 'jutiapa.csv', 'san_marcos.csv',
    'escuintla.csv', 'peten.csv', 'santa_rosa.csv'
]

# Leer y concatenar todos los archivos, omitiendo la primera fila y las dos últimas filas
dataframes = []
for file in files:
    df = pd.read_csv(f'./data_csv/{file}', sep=';', skiprows=1)
    # Calcular el número de filas a leer
    nrows = len(df) - 2
    df = df.head(nrows)
    dataframes.append(df)

combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df
# Out:
#               CODIGO DISTRITO  DEPARTAMENTO         MUNICIPIO  \
# 0      16-01-0138-46   16-031  ALTA VERAPAZ             COBAN
# 1      16-01-0139-46   16-031  ALTA VERAPAZ             COBAN
# 2      16-01-0140-46   16-031  ALTA VERAPAZ             COBAN
# 3      16-01-0141-46   16-005  ALTA VERAPAZ             COBAN
# 4      16-01-0142-46   16-005  ALTA VERAPAZ             COBAN
# ...              ...      ...           ...               ...
# 24546  06-14-0450-46   06-025    SANTA ROSA  NUEVA SANTA ROSA
# 24547  06-14-1766-46   06-025    SANTA ROSA  NUEVA SANTA ROSA
# 24548  06-14-1830-46   06-031    SANTA ROSA  NUEVA SANTA ROSA
# 24549  06-14-1996-46   06-023    SANTA ROSA  NUEVA SANTA ROSA
# 24550  06-14-2044-46   06-031    SANTA ROSA  NUEVA SANTA ROSA
#
#                                          ESTABLECIMIENTO  \
# 0                                          COLEGIO COBAN
# 1                       COLEGIO PARTICULAR MIXTO VERAPAZ
# 2                                COLEGIO "LA INMACULADA"
# 3               ESCUELA NACIONAL DE CIENCIAS COMERCIALES
# 4      INSTITUTO NORMAL MIXTO DEL NORTE 'EMILIO ROSAL...
# ...                                                  ...
# 24546    CENTRO EDUCATIVO NUESTRA SE�ORA DE LA ESPERANZA
# 24547                       COLEGIO DE COMPUTACION ACCES
# 24548    CENTRO EDUCATIVO NUESTRA SE�ORA DE LA ESPERANZA
# 24549              COLEGIO PARTICULAR MIXTO LA ESPERANZA
# 24550    CENTRO EDUCATIVO NUESTRA SE�ORA DE LA ESPERANZA
#
#                                     DIRECCION  TELEFONO  \
# 0      KM.2 SALIDA A SAN JUAN CHAMELCO ZONA 8  77945104
# 1                KM 209.5 ENTRADA A LA CIUDAD  77367402
# 2                   7A. AVENIDA 11-109 ZONA 6  78232301
# 3                       2A CALLE 11-10 ZONA 2  79514215
# 4                         3A AVE 6-23 ZONA 11  79521468
# ...                                       ...       ...
# 24546       CASER�O EL CHILTEPE, ALDEA CHAPAS  40175127
# 24547                      ALDEA EL RIACHUELO  78889145
# 24548        CASERIO EL CHILTEPE ALDEA CHAPAS  52004719
# 24549                      CABECERA MUNICIPAL  30667449
# 24550        CASERIO EL CHILTEPE ALDEA CHAPAS  52004719
#
#                             SUPERVISOR                        DIRECTOR  \
# 0      MERCEDES JOSEFINA TORRES GALVEZ       GUSTAVO ADOLFO SIERRA POP
# 1      MERCEDES JOSEFINA TORRES GALVEZ  GILMA DOLORES GUAY PAZ DE LEAL
# 2      MERCEDES JOSEFINA TORRES GALVEZ         VIRGINIA SOLANO SERRANO
# 3                  RUDY ADOLFO TOT OCH         HɃTOR ROLANDO CHUN POOU
# 4                  RUDY ADOLFO TOT OCH      VICTOR HUGO DOM͎GUEZ REYES
# ...                                ...                             ...
# 24546             ROBERTO GALVEZ DONIS            HUMBERTA RAMOS P�REZ
# 24547             ROBERTO GALVEZ DONIS  LIDIA ESTELA SALAZAR ARREDONDO
# 24548    JOEL ESTUARDO POCASANGRE FONG                             NaN
# 24549   CESAR EFRAIN BARRERA Y BARRERA          RAFAELA S�NCHEZ GARC�A
# 24550    JOEL ESTUARDO POCASANGRE FONG          HECTOR HERRERA HERRERA
#
#                NIVEL   SECTOR    AREA                 STATUS   MODALIDAD  \
# 0      DIVERSIFICADO  PRIVADO  URBANA                ABIERTA  MONOLINGUE
# 1      DIVERSIFICADO  PRIVADO  URBANA                ABIERTA  MONOLINGUE
# 2      DIVERSIFICADO  PRIVADO  URBANA                ABIERTA  MONOLINGUE
# 3      DIVERSIFICADO  OFICIAL  URBANA                ABIERTA  MONOLINGUE
# 4      DIVERSIFICADO  OFICIAL  URBANA                ABIERTA    BILINGUE
# ...              ...      ...     ...                    ...         ...
# 24546  DIVERSIFICADO  PRIVADO   RURAL                ABIERTA  MONOLINGUE
# 24547  DIVERSIFICADO  PRIVADO   RURAL                ABIERTA  MONOLINGUE
# 24548  DIVERSIFICADO  PRIVADO   RURAL  CERRADA TEMPORALMENTE  MONOLINGUE
# 24549  DIVERSIFICADO  PRIVADO  URBANA                ABIERTA  MONOLINGUE
# 24550  DIVERSIFICADO  PRIVADO   RURAL  CERRADA TEMPORALMENTE  MONOLINGUE
#
#           JORNADA             PLAN DEPARTAMENTAL
# 0        MATUTINA  DIARIO(REGULAR)  ALTA VERAPAZ
# 1        MATUTINA  DIARIO(REGULAR)  ALTA VERAPAZ
# 2        MATUTINA  DIARIO(REGULAR)  ALTA VERAPAZ
# 3        MATUTINA  DIARIO(REGULAR)  ALTA VERAPAZ
# 4      VESPERTINA  DIARIO(REGULAR)  ALTA VERAPAZ
# ...           ...              ...           ...
# 24546    MATUTINA  DIARIO(REGULAR)    SANTA ROSA
# 24547    MATUTINA  DIARIO(REGULAR)    SANTA ROSA
# 24548    MATUTINA  DIARIO(REGULAR)    SANTA ROSA
# 24549  VESPERTINA  DIARIO(REGULAR)    SANTA ROSA
# 24550       DOBLE  DIARIO(REGULAR)    SANTA ROSA
#
# [24551 rows x 17 columns]
